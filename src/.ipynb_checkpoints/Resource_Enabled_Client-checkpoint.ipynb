# %%
#https://www.youtube.com/watch?v=xdq6Gz33khQ

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/ilianacantu/opt/anaconda3/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/ilianacantu/opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ilianacantu/opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/ilianacantu/opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ilianacantu/opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)

# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
#get client id and secret at https://developer.spotify.com/
client_id = '64aef02fb8d248c18e98a4a171a9647b'
client_secret = '4215ece14af04410965d8f3101d518d9'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.perform_auth()
# Out:
# True

# %%
access_token = spotify.access_token

# %%
track_name = "Hello"
headers = {
    "Authorization": f"Bearer {access_token}"
}
endpoint = "https://api.spotify.com/v1/search"
data = urlencode({"q": track_name, "type": "track"})
print(data)

lookup_url = f"{endpoint}?{data}"
print(lookup_url)
r = requests.get(lookup_url, headers=headers)
print(r.status_code)

r.json()
# Out:
# q=Hello&type=track
# https://api.spotify.com/v1/search?q=Hello&type=track
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Hello&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj'},
#        'href': 'https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj',
#        'id': '0eDvMgVFoNV3TpwtrVCoTj',
#        'name': 'Pop Smoke',
#        'type': 'artist',
#        'uri': 'spotify:artist:0eDvMgVFoNV3TpwtrVCoTj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2MDU46hcBn3u94s46BOSdv'},
#      'href': 'https://api.spotify.com/v1/albums/2MDU46hcBn3u94s46BOSdv',
#      'id': '2MDU46hcBn3u94s46BOSdv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27346e1307c35579c3483ea7b03',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0246e1307c35579c3483ea7b03',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485146e1307c35579c3483ea7b03',
#        'width': 64}],
#      'name': 'Shoot For The Stars Aim For The Moon (Deluxe)',
#      'release_date': '2020-07-20',
#      'release_date_precision': 'day',
#      'total_tracks': 34,
#      'type': 'album',
#      'uri': 'spotify:album:2MDU46hcBn3u94s46BOSdv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj'},
#       'href': 'https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj',
#       'id': '0eDvMgVFoNV3TpwtrVCoTj',
#       'name': 'Pop Smoke',
#       'type': 'artist',
#       'uri': 'spotify:artist:0eDvMgVFoNV3TpwtrVCoTj'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'},
#       'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I',
#       'id': '31W5EY0aAly4Qieq6OFu6I',
#       'name': 'A Boogie Wit da Hoodie',
#       'type': 'artist',
#       'uri': 'spotify:artist:31W5EY0aAly4Qieq6OFu6I'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 190534,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72014370'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2r6OAV3WsYtXuXjvJ1lIDi'},
#     'href': 'https://api.spotify.com/v1/tracks/2r6OAV3WsYtXuXjvJ1lIDi',
#     'id': '2r6OAV3WsYtXuXjvJ1lIDi',
#     'is_local': False,
#     'name': 'Hello (feat. A Boogie Wit da Hoodie)',
#     'popularity': 88,
#     'preview_url': None,
#     'track_number': 30,
#     'type': 'track',
#     'uri': 'spotify:track:2r6OAV3WsYtXuXjvJ1lIDi'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3l0CmX0FuQjFxr8SK7Vqag'},
#        'href': 'https://api.spotify.com/v1/artists/3l0CmX0FuQjFxr8SK7Vqag',
#        'id': '3l0CmX0FuQjFxr8SK7Vqag',
#        'name': 'Clairo',
#        'type': 'artist',
#        'uri': 'spotify:artist:3l0CmX0FuQjFxr8SK7Vqag'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3NEDQmYF1roygFssVEwkwv'},
#      'href': 'https://api.spotify.com/v1/albums/3NEDQmYF1roygFssVEwkwv',
#      'id': '3NEDQmYF1roygFssVEwkwv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf94e27360806b5aa5025f93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf94e27360806b5aa5025f93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf94e27360806b5aa5025f93',
#        'width': 64}],
#      'name': 'diary 001',
#      'release_date': '2018-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:3NEDQmYF1roygFssVEwkwv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3l0CmX0FuQjFxr8SK7Vqag'},
#       'href': 'https://api.spotify.com/v1/artists/3l0CmX0FuQjFxr8SK7Vqag',
#       'id': '3l0CmX0FuQjFxr8SK7Vqag',
#       'name': 'Clairo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3l0CmX0FuQjFxr8SK7Vqag'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3lLHpTOJ11tWiUNGYN14gt'},
#       'href': 'https://api.spotify.com/v1/artists/3lLHpTOJ11tWiUNGYN14gt',
#       'id': '3lLHpTOJ11tWiUNGYN14gt',
#       'name': 'Rejjie Snow',
#       'type': 'artist',
#       'uri': 'spotify:artist:3lLHpTOJ11tWiUNGYN14gt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 135016,
#     'explicit': False,
#     'external_ids': {'isrc': 'US4HB1800005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qwt4xUIqQWCu1DJf96g2k'},
#     'href': 'https://api.spotify.com/v1/tracks/7qwt4xUIqQWCu1DJf96g2k',
#     'id': '7qwt4xUIqQWCu1DJf96g2k',
#     'is_local': False,
#     'name': 'Hello?',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7qwt4xUIqQWCu1DJf96g2k'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KW',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7uwVgw95fDHFF9U9KYkdS1'},
#      'href': 'https://api.spotify.com/v1/albums/7uwVgw95fDHFF9U9KYkdS1',
#      'id': '7uwVgw95fDHFF9U9KYkdS1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba9c5d4cba95e336ab92707f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba9c5d4cba95e336ab92707f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba9c5d4cba95e336ab92707f',
#        'width': 64}],
#      'name': 'Bachatas y reggaeton',
#      'release_date': '2020-12-18',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:7uwVgw95fDHFF9U9KYkdS1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#       'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#       'id': '1i8SpTcr7yvPOmcqrbnVXY',
#       'name': 'Ozuna',
#       'type': 'artist',
#       'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KW',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71610032'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0HFvv8LR8y64Kwe8SjPWyU'},
#     'href': 'https://api.spotify.com/v1/tracks/0HFvv8LR8y64Kwe8SjPWyU',
#     'id': '0HFvv8LR8y64Kwe8SjPWyU',
#     'is_local': False,
#     'name': 'Hello',
#     'popularity': 0,
#     'preview_url': None,
#     'track_number': 27,
#     'type': 'track',
#     'uri': 'spotify:track:0HFvv8LR8y64Kwe8SjPWyU'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dy5WNgIKQU6ezkpZs4y8z'},
#        'href': 'https://api.spotify.com/v1/artists/1dy5WNgIKQU6ezkpZs4y8z',
#        'id': '1dy5WNgIKQU6ezkpZs4y8z',
#        'name': 'ROLE MODEL',
#        'type': 'artist',
#        'uri': 'spotify:artist:1dy5WNgIKQU6ezkpZs4y8z'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5xNYe96E1oMXdS1FdboZZv'},
#      'href': 'https://api.spotify.com/v1/albums/5xNYe96E1oMXdS1FdboZZv',
#      'id': '5xNYe96E1oMXdS1FdboZZv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ab8bafa6da1f2e4c6cbfabfc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ab8bafa6da1f2e4c6cbfabfc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ab8bafa6da1f2e4c6cbfabfc',
#        'width': 64}],
#      'name': 'oh, how perfect',
#      'release_date': '2019-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5xNYe96E1oMXdS1FdboZZv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dy5WNgIKQU6ezkpZs4y8z'},
#       'href': 'https://api.spotify.com/v1/artists/1dy5WNgIKQU6ezkpZs4y8z',
#       'id': '1dy5WNgIKQU6ezkpZs4y8z',
#       'name': 'ROLE MODEL',
#       'type': 'artist',
#       'uri': 'spotify:artist:1dy5WNgIKQU6ezkpZs4y8z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 188546,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71919494'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7a2IJHzw9WJjoknwdnCop0'},
#     'href': 'https://api.spotify.com/v1/tracks/7a2IJHzw9WJjoknwdnCop0',
#     'id': '7a2IJHzw9WJjoknwdnCop0',
#     'is_local': False,
#     'name': 'hello!',
#     'popularity': 64,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7a2IJHzw9WJjoknwdnCop0'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fe3pszR2t4TOBVz41B1WR'},
#        'href': 'https://api.spotify.com/v1/artists/3Fe3pszR2t4TOBVz41B1WR',
#        'id': '3Fe3pszR2t4TOBVz41B1WR',
#        'name': 'The Oh Hellos',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Fe3pszR2t4TOBVz41B1WR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1a3UYpjNVB67soVfvtHoG8'},
#      'href': 'https://api.spotify.com/v1/albums/1a3UYpjNVB67soVfvtHoG8',
#      'id': '1a3UYpjNVB67soVfvtHoG8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a4f148bc554d01dbfbd93df0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a4f148bc554d01dbfbd93df0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a4f148bc554d01dbfbd93df0',
#        'width': 64}],
#      'name': 'The Oh Hellos EP',
#      'release_date': '2011-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:1a3UYpjNVB67soVfvtHoG8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fe3pszR2t4TOBVz41B1WR'},
#       'href': 'https://api.spotify.com/v1/artists/3Fe3pszR2t4TOBVz41B1WR',
#       'id': '3Fe3pszR2t4TOBVz41B1WR',
#       'name': 'The Oh Hellos',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Fe3pszR2t4TOBVz41B1WR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 256006,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCGJ1205481'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2c62Xf5Po1YSa1N6LOjPHy'},
#     'href': 'https://api.spotify.com/v1/tracks/2c62Xf5Po1YSa1N6LOjPHy',
#     'id': '2c62Xf5Po1YSa1N6LOjPHy',
#     'is_local': False,
#     'name': 'Hello My Old Heart',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/910ebbbe98672c77cfb41873799ddb95db363ab6?cid=64aef02fb8d248c18e98a4a171a9647b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2c62Xf5Po1YSa1N6LOjPHy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gMaNLQm7D9MornNILzdSl'},
#        'href': 'https://api.spotify.com/v1/artists/3gMaNLQm7D9MornNILzdSl',
#        'id': '3gMaNLQm7D9MornNILzdSl',
#        'name': 'Lionel Richie',
#        'type': 'artist',
#        'uri': 'spotify:artist:3gMaNLQm7D9MornNILzdSl'}],
#      'available_markets': ['CA', 'MX', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3alZBOvPaK3hgMEEymw4Yr'},
#      'href': 'https://api.spotify.com/v1/albums/3alZBOvPaK3hgMEEymw4Yr',
#      'id': '3alZBOvPaK3hgMEEymw4Yr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737ebe4ccb79ca0dc76356b9bb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027ebe4ccb79ca0dc76356b9bb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517ebe4ccb79ca0dc76356b9bb',
#        'width': 64}],
#      'name': "Can't Slow Down",
#      'release_date': '1983-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:3alZBOvPaK3hgMEEymw4Yr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gMaNLQm7D9MornNILzdSl'},
#       'href': 'https://api.spotify.com/v1/artists/3gMaNLQm7D9MornNILzdSl',
#       'id': '3gMaNLQm7D9MornNILzdSl',
#       'name': 'Lionel Richie',
#       'type': 'artist',
#       'uri': 'spotify:artist:3gMaNLQm7D9MornNILzdSl'}],
#     'available_markets': ['CA', 'MX', 'US'],
#     'disc_number': 1,
#     'duration_ms': 251106,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMO18390012'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0mHyWYXmmCB9iQyK18m3FQ'},
#     'href': 'https://api.spotify.com/v1/tracks/0mHyWYXmmCB9iQyK18m3FQ',
#     'id': '0mHyWYXmmCB9iQyK18m3FQ',
#     'is_local': False,
#     'name': 'Hello',
#     'popularity': 58,
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0mHyWYXmmCB9iQyK18m3FQ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#        'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#        'id': '6l3HvQ5sa6mXTsMTB19rO5',
#        'name': 'J. Cole',
#        'type': 'artist',
#        'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7viNUmZZ8ztn2UB4XB3jIL'},
#      'href': 'https://api.spotify.com/v1/albums/7viNUmZZ8ztn2UB4XB3jIL',
#      'id': '7viNUmZZ8ztn2UB4XB3jIL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736aca031ccc27d2e4dd829d14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026aca031ccc27d2e4dd829d14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516aca031ccc27d2e4dd829d14',
#        'width': 64}],
#      'name': '2014 Forest Hills Drive',
#      'release_date': '2014-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7viNUmZZ8ztn2UB4XB3jIL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#       'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#       'id': '6l3HvQ5sa6mXTsMTB19rO5',
#       'name': 'J. Cole',
#       'type': 'artist',
#       'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 219173,
#     'explicit': True,
#     'external_ids': {'isrc': 'USQX91402599'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/30Chv2SmIry70YwtmtaKnj'},
#     'href': 'https://api.spotify.com/v1/tracks/30Chv2SmIry70YwtmtaKnj',
#     'id': '30Chv2SmIry70YwtmtaKnj',
#     'is_local': False,
#     'name': 'Hello',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/811b0d64f02bbd3d641b958f95aa339bd887ba7e?cid=64aef02fb8d248c18e98a4a171a9647b',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:30Chv2SmIry70YwtmtaKnj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gi3jmwpUpNWdswT8eEprF'},
#        'href': 'https://api.spotify.com/v1/artists/7gi3jmwpUpNWdswT8eEprF',
#        'id': '7gi3jmwpUpNWdswT8eEprF',
#        'name': 'Conway Twitty',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gi3jmwpUpNWdswT8eEprF'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7jHxaZCVO8ITJOtQzexSI8'},
#      'href': 'https://api.spotify.com/v1/albums/7jHxaZCVO8ITJOtQzexSI8',
#      'id': '7jHxaZCVO8ITJOtQzexSI8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bc7f7609fce801806f47fdef',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bc7f7609fce801806f47fdef',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bc7f7609fce801806f47fdef',
#        'width': 64}],
#      'name': "Hello Darlin'",
#      'release_date': '1970-03-23',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:7jHxaZCVO8ITJOtQzexSI8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gi3jmwpUpNWdswT8eEprF'},
#       'href': 'https://api.spotify.com/v1/artists/7gi3jmwpUpNWdswT8eEprF',
#       'id': '7gi3jmwpUpNWdswT8eEprF',
#       'name': 'Conway Twitty',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gi3jmwpUpNWdswT8eEprF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 149133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMC16946870'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6vmAgl2y9MpoZKrVUXrPe5'},
#     'href': 'https://api.spotify.com/v1/tracks/6vmAgl2y9MpoZKrVUXrPe5',
#     'id': '6vmAgl2y9MpoZKrVUXrPe5',
#     'is_local': False,
#     'name': "Hello Darlin'",
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6vmAgl2y9MpoZKrVUXrPe5'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6iVo62B0bdTknRcrktCmak'},
#        'href': 'https://api.spotify.com/v1/artists/6iVo62B0bdTknRcrktCmak',
#        'id': '6iVo62B0bdTknRcrktCmak',
#        'name': 'KAI',
#        'type': 'artist',
#        'uri': 'spotify:artist:6iVo62B0bdTknRcrktCmak'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6xpxMAUhk8hiDTa5zT7F86'},
#      'href': 'https://api.spotify.com/v1/albums/6xpxMAUhk8hiDTa5zT7F86',
#      'id': '6xpxMAUhk8hiDTa5zT7F86',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27337ff46852249bdfc938beefa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0237ff46852249bdfc938beefa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485137ff46852249bdfc938beefa',
#        'width': 64}],
#      'name': 'KAI - The 1st Mini Album',
#      'release_date': '2020-11-30',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6xpxMAUhk8hiDTa5zT7F86'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6iVo62B0bdTknRcrktCmak'},
#       'href': 'https://api.spotify.com/v1/artists/6iVo62B0bdTknRcrktCmak',
#       'id': '6iVo62B0bdTknRcrktCmak',
#       'name': 'KAI',
#       'type': 'artist',
#       'uri': 'spotify:artist:6iVo62B0bdTknRcrktCmak'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 168253,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA302000607'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3LjS1vGAprMNthdyue5XZD'},
#     'href': 'https://api.spotify.com/v1/tracks/3LjS1vGAprMNthdyue5XZD',
#     'id': '3LjS1vGAprMNthdyue5XZD',
#     'is_local': False,
#     'name': 'Hello Stranger',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/39e9321b650d080f6042a919b1e80a54ad682f3d?cid=64aef02fb8d248c18e98a4a171a9647b',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3LjS1vGAprMNthdyue5XZD'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6blEmsLU25ewy8hHtgZaSL'},
#        'href': 'https://api.spotify.com/v1/artists/6blEmsLU25ewy8hHtgZaSL',
#        'id': '6blEmsLU25ewy8hHtgZaSL',
#        'name': 'Jazmin Bean',
#        'type': 'artist',
#        'uri': 'spotify:artist:6blEmsLU25ewy8hHtgZaSL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2SVRzumTLUTdoHgYNQ4Rh9'},
#      'href': 'https://api.spotify.com/v1/albums/2SVRzumTLUTdoHgYNQ4Rh9',
#      'id': '2SVRzumTLUTdoHgYNQ4Rh9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eea4d8ef4ad2b9b0a7f00d37',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eea4d8ef4ad2b9b0a7f00d37',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eea4d8ef4ad2b9b0a7f00d37',
#        'width': 64}],
#      'name': 'Worldwide Torture',
#      'release_date': '2020-11-11',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2SVRzumTLUTdoHgYNQ4Rh9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6blEmsLU25ewy8hHtgZaSL'},
#       'href': 'https://api.spotify.com/v1/artists/6blEmsLU25ewy8hHtgZaSL',
#       'id': '6blEmsLU25ewy8hHtgZaSL',
#       'name': 'Jazmin Bean',
#       'type': 'artist',
#       'uri': 'spotify:artist:6blEmsLU25ewy8hHtgZaSL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 151400,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZHN81940760'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/22FniXvTKV9IC6IhxCpYve'},
#     'href': 'https://api.spotify.com/v1/tracks/22FniXvTKV9IC6IhxCpYve',
#     'id': '22FniXvTKV9IC6IhxCpYve',
#     'is_local': False,
#     'name': 'Hello Kitty',
#     'popularity': 63,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:22FniXvTKV9IC6IhxCpYve'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#        'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#        'id': '0NB5HROxc8dDBXpkIi1v3d',
#        'name': 'Remi Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/55L7SoSuzXa9XbyQfrT9AJ'},
#      'href': 'https://api.spotify.com/v1/albums/55L7SoSuzXa9XbyQfrT9AJ',
#      'id': '55L7SoSuzXa9XbyQfrT9AJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a2aa35c7e9afcf49a5fb069',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a2aa35c7e9afcf49a5fb069',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a2aa35c7e9afcf49a5fb069',
#        'width': 64}],
#      'name': 'Hello Hello Hello (Polo & Pan Remix)',
#      'release_date': '2020-07-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:55L7SoSuzXa9XbyQfrT9AJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#       'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#       'id': '0NB5HROxc8dDBXpkIi1v3d',
#       'name': 'Remi Wolf',
#       'type': 'artist',
#       'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/45yEuthJ9yq1rNXAOpBnqM'},
#       'href': 'https://api.spotify.com/v1/artists/45yEuthJ9yq1rNXAOpBnqM',
#       'id': '45yEuthJ9yq1rNXAOpBnqM',
#       'name': 'Polo & Pan',
#       'type': 'artist',
#       'uri': 'spotify:artist:45yEuthJ9yq1rNXAOpBnqM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235800,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12002380'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0DWTIW018T4iqubyYdU43r'},
#     'href': 'https://api.spotify.com/v1/tracks/0DWTIW018T4iqubyYdU43r',
#     'id': '0DWTIW018T4iqubyYdU43r',
#     'is_local': False,
#     'name': 'Hello Hello Hello - Polo & Pan Remix',
#     'popularity': 64,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0DWTIW018T4iqubyYdU43r'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2BtE7qm1qzM80p9vLSiXkj'},
#      'href': 'https://api.spotify.com/v1/albums/2BtE7qm1qzM80p9vLSiXkj',
#      'id': '2BtE7qm1qzM80p9vLSiXkj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273692d9189b2bd75525893f0c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02692d9189b2bd75525893f0c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851692d9189b2bd75525893f0c1',
#        'width': 64}],
#      'name': 'Magical Mystery Tour (Remastered)',
#      'release_date': '1967-11-27',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2BtE7qm1qzM80p9vLSiXkj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
# ...
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KFGq3710E0bF0n9D9gK4z'},
#      'href': 'https://api.spotify.com/v1/albums/1KFGq3710E0bF0n9D9gK4z',
#      'id': '1KFGq3710E0bF0n9D9gK4z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273babcecae4a50a6eef398b493',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02babcecae4a50a6eef398b493',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851babcecae4a50a6eef398b493',
#        'width': 64}],
#      'name': 'Hello, World',
#      'release_date': '2018-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1KFGq3710E0bF0n9D9gK4z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jOY91ZU7kn86slH3fBbaD'},
#       'href': 'https://api.spotify.com/v1/artists/7jOY91ZU7kn86slH3fBbaD',
#       'id': '7jOY91ZU7kn86slH3fBbaD',
#       'name': 'Louie Zong',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jOY91ZU7kn86slH3fBbaD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 115374,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4DW1845657'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21AUdfi6fLFDp9JuNcHsfS'},
#     'href': 'https://api.spotify.com/v1/tracks/21AUdfi6fLFDp9JuNcHsfS',
#     'id': '21AUdfi6fLFDp9JuNcHsfS',
#     'is_local': False,
#     'name': 'Hello, World',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6566fa6393ca302a6019b5b6fc04a562d6f9bbd2?cid=64aef02fb8d248c18e98a4a171a9647b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:21AUdfi6fLFDp9JuNcHsfS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NnoRcD3WkqC9aouHyE8YY'},
#        'href': 'https://api.spotify.com/v1/artists/0NnoRcD3WkqC9aouHyE8YY',
#        'id': '0NnoRcD3WkqC9aouHyE8YY',
#        'name': 'Trey Parker',
#        'type': 'artist',
#        'uri': 'spotify:artist:0NnoRcD3WkqC9aouHyE8YY'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3zUCHzvbTmCOZoY750yHPB'},
#        'href': 'https://api.spotify.com/v1/artists/3zUCHzvbTmCOZoY750yHPB',
#        'id': '3zUCHzvbTmCOZoY750yHPB',
#        'name': 'Robert Lopez',
#        'type': 'artist',
#        'uri': 'spotify:artist:3zUCHzvbTmCOZoY750yHPB'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/57lz7wkyFThB2w4UvpxnUS'},
#        'href': 'https://api.spotify.com/v1/artists/57lz7wkyFThB2w4UvpxnUS',
#        'id': '57lz7wkyFThB2w4UvpxnUS',
#        'name': 'Matt Stone',
#        'type': 'artist',
#        'uri': 'spotify:artist:57lz7wkyFThB2w4UvpxnUS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5yauUuXppqUj2ulor38hvI'},
#      'href': 'https://api.spotify.com/v1/albums/5yauUuXppqUj2ulor38hvI',
#      'id': '5yauUuXppqUj2ulor38hvI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d9cd8917de31257e2ac920a9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d9cd8917de31257e2ac920a9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d9cd8917de31257e2ac920a9',
#        'width': 64}],
#      'name': 'The Book Of Mormon (Original Broadway Cast Recording)',
#      'release_date': '2011-05-17',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5yauUuXppqUj2ulor38hvI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0GxSAKOw8AV0JsEQ0HYY4b'},
#       'href': 'https://api.spotify.com/v1/artists/0GxSAKOw8AV0JsEQ0HYY4b',
#       'id': '0GxSAKOw8AV0JsEQ0HYY4b',
#       'name': 'Andrew Rannells',
#       'type': 'artist',
#       'uri': 'spotify:artist:0GxSAKOw8AV0JsEQ0HYY4b'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4dSQICBjdUIp5iK6RRU2bY'},
#       'href': 'https://api.spotify.com/v1/artists/4dSQICBjdUIp5iK6RRU2bY',
#       'id': '4dSQICBjdUIp5iK6RRU2bY',
#       'name': 'Josh Gad',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dSQICBjdUIp5iK6RRU2bY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ypbxQ7Pb5JKm2ulHXDcBP'},
#       'href': 'https://api.spotify.com/v1/artists/4ypbxQ7Pb5JKm2ulHXDcBP',
#       'id': '4ypbxQ7Pb5JKm2ulHXDcBP',
#       'name': "Rory O'Malley",
#       'type': 'artist',
#       'uri': 'spotify:artist:4ypbxQ7Pb5JKm2ulHXDcBP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6b1coNssyWbKkbgZfK9MB5'},
#       'href': 'https://api.spotify.com/v1/artists/6b1coNssyWbKkbgZfK9MB5',
#       'id': '6b1coNssyWbKkbgZfK9MB5',
#       'name': 'Kevin Duda',
#       'type': 'artist',
#       'uri': 'spotify:artist:6b1coNssyWbKkbgZfK9MB5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xWxKaEFEKU3r7AUzUKylT'},
#       'href': 'https://api.spotify.com/v1/artists/6xWxKaEFEKU3r7AUzUKylT',
#       'id': '6xWxKaEFEKU3r7AUzUKylT',
#       'name': 'Clark Johnsen',
#       'type': 'artist',
#       'uri': 'spotify:artist:6xWxKaEFEKU3r7AUzUKylT'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4MYUIgtNTRdEfksW6IwvAe'},
#       'href': 'https://api.spotify.com/v1/artists/4MYUIgtNTRdEfksW6IwvAe',
#       'id': '4MYUIgtNTRdEfksW6IwvAe',
#       'name': 'Justin Bohon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MYUIgtNTRdEfksW6IwvAe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7prZJzDK9Eaidya20kUciB'},
#       'href': 'https://api.spotify.com/v1/artists/7prZJzDK9Eaidya20kUciB',
#       'id': '7prZJzDK9Eaidya20kUciB',
#       'name': 'Brian Sears',
#       'type': 'artist',
#       'uri': 'spotify:artist:7prZJzDK9Eaidya20kUciB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1A4dOeSiYZ0yBf6l5uYY7m'},
#       'href': 'https://api.spotify.com/v1/artists/1A4dOeSiYZ0yBf6l5uYY7m',
#       'id': '1A4dOeSiYZ0yBf6l5uYY7m',
#       'name': 'Scott Barnhardt',
#       'type': 'artist',
#       'uri': 'spotify:artist:1A4dOeSiYZ0yBf6l5uYY7m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5OPT8oIrU42hqfKMJv0b5B'},
#       'href': 'https://api.spotify.com/v1/artists/5OPT8oIrU42hqfKMJv0b5B',
#       'id': '5OPT8oIrU42hqfKMJv0b5B',
#       'name': 'Benjamin Schrader',
#       'type': 'artist',
#       'uri': 'spotify:artist:5OPT8oIrU42hqfKMJv0b5B'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7tihd0CgVerCoDl6LeDHQW'},
#       'href': 'https://api.spotify.com/v1/artists/7tihd0CgVerCoDl6LeDHQW',
#       'id': '7tihd0CgVerCoDl6LeDHQW',
#       'name': 'Lewis Cleale',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tihd0CgVerCoDl6LeDHQW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/32oXmsd7TLzVccshoWY0mm'},
#       'href': 'https://api.spotify.com/v1/artists/32oXmsd7TLzVccshoWY0mm',
#       'id': '32oXmsd7TLzVccshoWY0mm',
#       'name': 'Jason Michael Snow',
#       'type': 'artist',
#       'uri': 'spotify:artist:32oXmsd7TLzVccshoWY0mm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSK31192101'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/08hlFtp8y9S6YZmjBNvQ1I'},
#     'href': 'https://api.spotify.com/v1/tracks/08hlFtp8y9S6YZmjBNvQ1I',
#     'id': '08hlFtp8y9S6YZmjBNvQ1I',
#     'is_local': False,
#     'name': 'Hello!',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6048fb830712558ff5f966949874e9fb4ff6bc0b?cid=64aef02fb8d248c18e98a4a171a9647b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:08hlFtp8y9S6YZmjBNvQ1I'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5jZeLexrrwGNUy6nv7tzdr'},
#        'href': 'https://api.spotify.com/v1/artists/5jZeLexrrwGNUy6nv7tzdr',
#        'id': '5jZeLexrrwGNUy6nv7tzdr',
#        'name': 'C4C',
#        'type': 'artist',
#        'uri': 'spotify:artist:5jZeLexrrwGNUy6nv7tzdr'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uJZwuCV2hXbQDSdJvj198'},
#        'href': 'https://api.spotify.com/v1/artists/1uJZwuCV2hXbQDSdJvj198',
#        'id': '1uJZwuCV2hXbQDSdJvj198',
#        'name': 'kokoro',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uJZwuCV2hXbQDSdJvj198'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4dbwtwsD09MP1W29TWRdOg'},
#      'href': 'https://api.spotify.com/v1/albums/4dbwtwsD09MP1W29TWRdOg',
#      'id': '4dbwtwsD09MP1W29TWRdOg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730ff922782c2e0ceffa4a611b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020ff922782c2e0ceffa4a611b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510ff922782c2e0ceffa4a611b',
#        'width': 64}],
#      'name': "L'aventure EP",
#      'release_date': '2020-02-14',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4dbwtwsD09MP1W29TWRdOg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5jZeLexrrwGNUy6nv7tzdr'},
#       'href': 'https://api.spotify.com/v1/artists/5jZeLexrrwGNUy6nv7tzdr',
#       'id': '5jZeLexrrwGNUy6nv7tzdr',
#       'name': 'C4C',
#       'type': 'artist',
#       'uri': 'spotify:artist:5jZeLexrrwGNUy6nv7tzdr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uJZwuCV2hXbQDSdJvj198'},
#       'href': 'https://api.spotify.com/v1/artists/1uJZwuCV2hXbQDSdJvj198',
#       'id': '1uJZwuCV2hXbQDSdJvj198',
#       'name': 'kokoro',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uJZwuCV2hXbQDSdJvj198'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 149647,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAEQ2060868'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7bza6R254w7hZyNO9zaIxc'},
#     'href': 'https://api.spotify.com/v1/tracks/7bza6R254w7hZyNO9zaIxc',
#     'id': '7bza6R254w7hZyNO9zaIxc',
#     'is_local': False,
#     'name': 'Hello',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ed17b198f2f7e76dbc841828af65540d3aa05ada?cid=64aef02fb8d248c18e98a4a171a9647b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7bza6R254w7hZyNO9zaIxc'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Hello&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 80726}}
